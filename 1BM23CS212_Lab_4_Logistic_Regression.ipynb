# %%
import pandas as pd
df=pd.read_csv("HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
print("First 5 rows of the DataFrame:")
df.head()
# Out:
# First 5 rows of the DataFrame:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
# ...

# %%
print("DataFrame Info:")
df.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
print("Descriptive statistics for numerical columns:")
df.describe()
# Out:
# Descriptive statistics for numerical columns:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
print("Missing values in each column:")
df.isnull().sum()
# Out:
# Missing values in each column:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
print("Distribution of the target variable 'left':")
df['left'].value_counts()
# Out:
# Distribution of the target variable 'left':
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
print("Correlation matrix of numerical columns:")
df.select_dtypes(include=['number']).corr()
# Out:
# Correlation matrix of numerical columns:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# ...

# %%
print("Retention rate by Department:")
print(df.groupby('Department')['left'].mean())
print("\nRetention rate by Salary:")
print(df.groupby('salary')['left'].mean())
# Out:
# Retention rate by Department:
# Department
# IT             0.222494
# RandD          0.153748
# accounting     0.265971
# hr             0.290934
# management     0.144444
# marketing      0.236597
# product_mng    0.219512
# sales          0.244928
# support        0.248991
# technical      0.256250
# Name: left, dtype: float64
#
# Retention rate by Salary:
# salary
# high      0.066289
# low       0.296884
# medium    0.204313
# Name: left, dtype: float64

# %%
retention_rate_by_salary = df.groupby('salary')['left'].mean().reset_index()
print("Retention rate by Salary:")
print(retention_rate_by_salary)
# Out:
# Retention rate by Salary:
#    salary      left
# 0    high  0.066289
# 1     low  0.296884
# 2  medium  0.204313

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.barplot(x='salary', y='left', data=retention_rate_by_salary, palette='viridis')
plt.title('Retention Rate by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Retention Rate')
plt.show()
# Out:
# /tmp/ipykernel_246/3237180009.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='salary', y='left', data=retention_rate_by_salary, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.barplot(x='salary', y='left', data=retention_rate_by_salary, palette='viridis', hue='salary', legend=False)
plt.title('Retention Rate by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Retention Rate')
plt.show()

# %%
retention_rate_by_department = df.groupby('Department')['left'].mean().reset_index()
print("Retention rate by Department:")
print(retention_rate_by_department)
# Out:
# Retention rate by Department:
#     Department      left
# 0           IT  0.222494
# 1        RandD  0.153748
# 2   accounting  0.265971
# 3           hr  0.290934
# 4   management  0.144444
# 5    marketing  0.236597
# 6  product_mng  0.219512
# 7        sales  0.244928
# 8      support  0.248991
# 9    technical  0.256250

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x='Department', y='left', data=retention_rate_by_department, palette='viridis', hue='Department', legend=False)
plt.title('Retention Rate by Department')
plt.xlabel('Department')
plt.ylabel('Retention Rate')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
impactful_features = ['satisfaction_level', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 'average_montly_hours', 'salary', 'Department']
X = df[impactful_features]
y = df['left']

print("Selected features (X) head:")
print(X.head())
print("\nTarget variable (y) head:")
print(y.head())
# Out:
# Selected features (X) head:
#    satisfaction_level  time_spend_company  Work_accident  \
# 0                0.38                   3              0
# 1                0.80                   6              0
# 2                0.11                   4              0
# 3                0.72                   5              0
# 4                0.37                   3              0
#
#    promotion_last_5years  average_montly_hours  salary Department
# 0                      0                   157     low      sales
# 1                      0                   262  medium      sales
# 2                      0                   272  medium      sales
# 3                      0                   223     low      sales
# 4                      0                   159     low      sales
#
# Target variable (y) head:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %%
X = pd.get_dummies(X, columns=['salary', 'Department'], drop_first=True)
print("Features (X) after one-hot encoding:")
print(X.head())
# Out:
# Features (X) after one-hot encoding:
#    satisfaction_level  time_spend_company  Work_accident  \
# 0                0.38                   3              0
# 1                0.80                   6              0
# 2                0.11                   4              0
# 3                0.72                   5              0
# 4                0.37                   3              0
#
#    promotion_last_5years  average_montly_hours  salary_low  salary_medium  \
# 0                      0                   157        True          False
# 1                      0                   262       False           True
# 2                      0                   272       False           True
# 3                      0                   223        True          False
# 4                      0                   159        True          False
#
#    Department_RandD  Department_accounting  Department_hr  \
# 0             False                  False          False
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (10499, 16)
# Shape of X_test: (4500, 16)
# Shape of y_train: (10499,)
# Shape of y_test: (4500,)

# %%
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
model = LogisticRegression(random_state=42, solver='liblinear') # Using 'liblinear' solver for small datasets and L1/L2 regularization

# Train the model
model.fit(X_train, y_train)

print("Logistic Regression model trained successfully.")
# Out:
# Logistic Regression model trained successfully.

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate and print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")

# Generate and print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.7631
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86      3428
#            1       0.51      0.25      0.33      1072
#
#     accuracy                           0.76      4500
#    macro avg       0.65      0.59      0.59      4500
# weighted avg       0.73      0.76      0.73      4500
